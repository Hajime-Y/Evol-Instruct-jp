# %%
# !python main.py \
# 	--input_file "./test_data/test_hh-rlhf-ja.jsonl" \
# 	--output_file "./test_output/test_generated.json" \
# 	--eliminated_file "./test_output/test_eliminated.json" \
# 	--model "mistralai/Mixtral-8x22B-Instruct-v0.1" \
# 	--generations 4 \
# 	--num_instructions_to_generate 10
# !python main.py \
# 	--input_file "./data/alpaca_seed_tasks_jp.jsonl" \
# 	--output_file "./output/new_generation.json" \
# 	--eliminated_file "./output/eliminated.json" \
# 	--model "mistralai/Mixtral-8x22B-Instruct-v0.1" \
# 	--generations 3 \
# 	--num_instructions_to_generate 40 \
# 	--subset_size 10 \
# 	--start_subset_index 6
# !python main.py \
# 	--input_file "./test_data/test.jsonl" \
# 	--output_file "./test_output/test_generated_for_check_diversity_v1.3.json" \
# 	--eliminated_file "./test_output/test_eliminated_for_check_diversity_v1.3.json" \
# 	--model "mistralai/Mixtral-8x22B-Instruct-v0.1" \
# 	--generations 6 \
# 	--num_instructions_to_generate 60
# !python main.py \
# 	--input_file "./data/alpaca_seed_tasks_jp.jsonl" \
# 	--output_file "./output/generated_20240511.json" \
# 	--eliminated_file "./output/eliminated_20240511.json" \
# 	--model "mistralai/Mixtral-8x22B-Instruct-v0.1" \
# 	--generations 5 \
# 	--num_instructions_to_generate 500
# !python main.py \
	--input_file "./data/hh-rlhf-49k-ja.jsonl" \
	--output_file "./output/generation_20240512_v6.json" \
	--eliminated_file "./output/eliminated_20240512_v6.json" \
	--model "mistralai/Mixtral-8x22B-Instruct-v0.1" \
	--hallucination_check_model "mistralai/Mixtral-8x7B-Instruct-v0.1" \
	--generations 3 \
	--num_instructions_to_generate 20 \
	--subset_size 50
# Out:
# 開始：保存ファイルに既に0件のInstructionがあります。
# 　　　20件を目標に生成を開始し、超えた場合自動でInstructionの生成を停止します。
# 　　　進化世代数は 4 世代に設定されています。
# ＊Evolution Progress:   0%|                              | 0/20 [00:00<?, ?it/s]
# subset0から進化を開始します。
#
# Subset Progress:   0%|                                  | 0/989 [00:00<?, ?it/s]
#
# Generation Progress:   0%|                                | 0/4 [00:00<?, ?it/s]check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: FBIとCIAの違いは何ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: どのくらいの頻度で教会に行くべきですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: Xファイルのキャラクターフォックスモルダーについて説明できますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: ケチャップの汚れはデニムのズボンから出てきますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: エグゼクティブレジデンスや翼や敷地など、ホワイトハウスの内部について教えてください。
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 結婚を成功させるための秘密は何だと思いますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 自家製のマラカをどのように作りますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: タチの動きを十分に見つけるのを手伝ってもらえますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: サンタクロースは本物ではないと子供に伝えるべきですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 菜食主義者は感謝祭のために何を食べますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: Googleマップはどのようにして地球のこのような現実的なデータベースを作成しましたか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: ポップコーンでクリスマスガーランドを作るにはどうすればよいですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 子犬工場が何であるか、そして人々が犬から犬を買わないと言う理由を説明できますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: チェスの演奏方法を学ぶにはどうすればよいですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 死刑は痛いですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: あなたが通常チップするプロバイダーの詳細なリストを教えてください。
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 最高裁判所には3人の女性正義があります。それらの名称は何ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 私は西オーストラリアへの旅行を計画しています、そして私はロンドンからどこに飛ぶことができますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 憲法上の君主制とは何ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 良い衣装を作る子供たちのテレビ番組や映画のかわいいキャラクターは何ですか？たとえば、ミニオン。アルファベット順にリストを教えてください。
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: なぜ高速がソニックブームを作成するのですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 子供たちは何時間宿題をするべきですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: きしむドアをどのように修理しますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
#
#
# Generation Progress:  25%|██████                  | 1/4 [00:13<00:39, 13.31s/it]check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 細胞膜を構成するたんぱく質を含む、鶏肉スープは、風邪を引いたときに、体内の免疫力を高める役割を果たします。このスープが、体の快心効果につながる具体的な機序を説明してください。
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: さくらの栽培方法を知りたくて、どうぞおしえてくださいね。
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 私は、4000枚のカードを使用した巨大なトランプ城を作り始めており、完成させるための最適な方法があるか分からず困っています。
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 米国の憲法が設立されてから、多くの修正が加えられました。そのうち、最も顕著な修正と追加には、何があり、それらはどのように米国の憲法を影響したのですか？また、それらの修正や追加が米国の社会、政治、経済に及ぼした影響についても教えてください。
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
#
#
# Generation Progress:  50%|████████████            | 2/4 [00:23<00:22, 11.27s/it]check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 膝のパッドは膝の怪我への効果は何ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
#
#
# Generation Progress:  75%|██████████████████      | 3/4 [00:30<00:09,  9.42s/it]
#
# Generation Progress: 100%|████████████████████████| 4/4 [00:58<00:00, 14.69s/it]
# 4件のInstructionを追加しました。
# ＊Evolution Progress:  20%|████▍                 | 4/20 [00:59<03:56, 14.78s/it]
# Subset Progress:   0%|                       | 1/989 [00:59<16:11:53, 59.02s/it]
#
# Generation Progress:   0%|                                | 0/4 [00:00<?, ?it/s]check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: なぜロシアはそのような奇妙なアルファベットを持っているのですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 最高のテイスティング玉ねぎは何ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 勢いの保存の物理学の概念を説明できますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 炭水化物のない食事の利点は何ですか
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: サクラメントは何で知られていますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: ケルト音楽の何が明確ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: やあ！私の犬は食べ物を物ggingいて、この行動を止めようとするのに助けが必要です
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: なぜ米国のネイティブ文化が雨を降らそうとして雨の踊りをしたのですか？彼らはそれが天気を変えるだろうと本当に信じていましたか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: ネイティブアメリカンは、座っている雄牛のような動物と記述的な名前を誰に持っていましたか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 大きなクランチ理論は科学コミュニティ内でまだよく受け入れられていますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 私の財産のネイティブツリーを削減することが合法かどうかを確認できますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: チーズをどのようにフリーズしますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 英国帝国が歴史上侵略した国の数を教えてください。
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: なぜコーリー・ブッカーは大統領選挙から脱落したのですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: インディアナ州の数字を教えてください
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 大きな岩を動かすにはどうすればよいですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 治療可能であると治療可能である状態の違いは何ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: リスは私の鳥の餌箱からすべての鳥の種を食べ続けます。どうすればそれらを締め出すことができますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: なぜカーダシアンはとても有名ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: Make a Wish Foundationの使命は何ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 私はアフリカのドラム音楽を楽しんでいます。伝統的に、ドラムの歌は、距離を越えて他の部族に伝えたと聞いています。本当？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: この記事を2つの短い文章にまとめてください：The Wonders by Elena Medel Review  - スペインの女性の詩的な肖像画2人の労働者階級の女性の生活は、この小説には2つの物語がありますが、それぞれが2つの物語があります。切り取られ、2つの断片が一緒にシャッフルされました。彼らは、コンサバターがイコノクラストの抱きしめによって残された破片を再組み立てし、関係のない作品のコラージュを作る教会の窓と同じように、イライラし、輝かしい照明の瞬間に満ちた複合絵を形成します。ここでは、聖人の手が祝福の中で手を伸ばします。そこには、鼻の悪魔のゆるい顔をしています。愛情を込めて実行されたカーテンの断片の散乱。どこでも空、汚れ、明るい色の垣間見る。スパンの作家エレナ・メデルは詩人であり、彼女は詩人が持続的な物語よりも重要な瞬間を好む。彼女の最初の小説では、彼女は私たちに2人の女性のビネットを与えてくれます。マリアはアリシアの祖母ですが、彼らはお互いを知りません。最後のセクションでは、2018年の女性のストライキの間に、彼らは無意識のうちに出会うだけで、通り過ぎるだけです。彼らの生活はお互いに反響します - どちらも野心を放棄し、平凡な男性と感情的に作ることで疲れ果てていますが、彼らはまた反対です。アリシアは、他の人や自分自身に対する軽emptに駆り立てられ、守られていて、警戒されています。マリアの物語はフェミニストのたとえ話です。誘惑され、搾取された非難のない少女は、最終的には中年で女性グループの共同設立者として自尊心を感じます。アリシアの物語は暗いです - 恵まれない少女は恐ろしい慣習を得て感情的に閉鎖し、彼女の賢く、怒っている心を思い出し、無差別なセックスに有利な愛を拒否するかもしれないものを麻痺させる仕事を選びます。声、そして時系列の秩序から。大人のアリシアは毎晩吊り下げられた体について夢を見て、父親が自分自身を絞首刑にしたことを発見するずっと前に、恐ろしく揺れ、アリシア自身が中等学校に新しく到着したことが足首にぶら下がっていると聞く前に、さらに長く揺れていることを知っていますジムの屋根ビームから、彼女のrog慢を嫌った子供たちによって。タイムプリーツと折りたたみます。私たちは、両方の女性が男性の弱点に耐えているのを見て、彼らがそれらの男性に会うのを見る前に。私たちは斜めにしか学びません、そして、混乱した順序で、中間女性のライフストーリー - マリアの娘でありアリシアの母親であり、その両方に置き去りにされています。この断片化の効果は、これらの個々の女性の生活を作ることです労働者階級のスペインの女性の集合的な写真。軽いタッチで、メデルは徐々に驚異的な変化を伝えます。アリシアの偉大な叔父は、コルドバの近所に下水道がなかったことを覚えています。2人の女性がオフィスクリーニングの仕事について議論し、バーの単一トイレでおしっこをするために列に並んでいる共産主義に投票します。マドリードの公共交通機関システムの拡散は、都市計画の観点からではなく、遅いシフトの後に旅行する女性の足と背中の痛みのある足と背中で、家から長い道のりを預けているバスで、恐ろしいことで鮮やかに感じられます。あまりにも多くの暗い出入り口がある照らされた通りに沿ってまだ歩いています。メデルが長年にわたって私たちを迅速に運んだときのパッセージは銃口になりますが、彼女がスローダウンして焦点を締めると、特定の事件が輝きます。老婦人マリアは、彼女の聖人の日のために特別なドレスを着たいと思っています。彼らの関係は、その複雑さ、つまり哀れみ、退屈、優しさ、怒りなどの繊細な感謝で説明されています。最終的に彼女の赤いドレスにボタンを入れて、老婦人は死にます。フランコ将軍も亡くなり、州に横たわっています。誰もが彼に会いに行きました。最終的にマリアは彼女を助けるために別の召使を見つけます。2人の女性は、雇用主の名前と住所で自分自身を識別しています。「私は3階のドニャシシの女の子です。」生と死の管理を委ねられて、彼らは適切な紹介に値するために、自分自身にさえあまりにも少ない説明をしています。これは、グリブの要約を回避する本です。それは貧困についてですが、アリシアの性質は比較的豊かであることによって歪められています。それはフェミニズムについてですが、最も聖なる2人のキャラクターは男性です。マリアの兄弟チコ、彼女が飼う余裕のない赤ちゃんを育て、大学への彼自身の希望と教育のキャリアを犠牲にします。彼女の恋人のペドロは、彼の無力な老人や精神的に病気の兄弟に非常に優れていることで彼女とのチャンスを台無しにします。それが説明する社会のように、メデルの小説は厳しいです。時々混乱しています。それは性的政治や資本主義に関する一般化に失効します。しかし、そのように、壊れてステンドグラスの窓を作り直し、大胆に独創的な構造と美しさの閃光を持っています。
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: イエローストーンのガイザーを訪問するための指示を教えてください。
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
#
#
# Generation Progress:  25%|██████                  | 1/4 [00:15<00:46, 15.35s/it]check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 嫌気な顔をする子どもに、生理食塩水鼻スプレーを使う理由を教えてください。
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 心配なバイレンスとプラグについて教えていただきたいのですが、まずはそれらの2つの違いをおしえてください。
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 生クリーム、マスカルポーネ、モントブリアンがあります。これらのうち、軽いスープの作り方で代替するのに最適なのはどれでしょうか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
#
#
# Generation Progress:  50%|████████████            | 2/4 [00:21<00:20, 10.11s/it]check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 最近、猫を飼っているのですが、自分のケースでは、尿症の症状が Februari に出てしまい、特別な食品に変更しなければならなくなりました。そのため、FUS 症状を軽減できるような食品を探しています。おすすめの猫フードがありましたら、ご教授頂けますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
#
#
# Generation Progress:  75%|██████████████████      | 3/4 [00:27<00:08,  8.28s/it]check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 血糖濃度が不安定になる危険を避けるため、人体はどのようによくある糖尿病の状態を回避していますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
#
#
# Generation Progress: 100%|████████████████████████| 4/4 [00:52<00:00, 13.17s/it]
# 5件のInstructionを追加しました。
# ＊Evolution Progress:  45%|█████████▉            | 9/20 [01:52<02:13, 12.09s/it]
# Subset Progress:   0%|                       | 2/989 [01:51<15:12:01, 55.44s/it]
#
# Generation Progress:   0%|                                | 0/4 [00:00<?, ?it/s]check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: シーモスの実証済みの利点は何ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: から始まる現代の男の子の名前は何ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: IRS監査とは何ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 私は学校のミツバチに関するレポートを書いています、彼らが蜂蜜を作る方法を教えてください。
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: こんにちは。私のためにこの一節のすべての文字を大文字にしてくれませんか？シンプルなカヌーから派手なクルーズ船まで、学生はこの有益な本のあらゆる種類の船舶について学びます。この本は、仕事と遊びに使用されるボートの歴史と発展をたどります。写真とイラストはテキストをサポートしています。
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: ダイヤモンドが4文でどのように形成されるか教えてもらえますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: ジプシー馬とは何ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: ウェイトウォッチャーは良いダイエット計画ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: マネーボールは実話でしたか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 人々はどのようにして難聴を得るのですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: ポーカーは運のゲームですか、それともスキルですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 私はフランスの新聞でニュース記事を読もうとしていますが、残念ながらウェブサイトの翻訳機能は機能していません。この見出しから始めて、私のためにいくつかの段落を翻訳することは可能ですか？
# le niqab auはソビエトのインディアンを支払います
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: チョコレートカップケーキのレシピを入手してください
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: どんな犬があまり流さないのですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 2型糖尿病患者はすべてインスリン注射を必要としますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 1950年代の最高の映画は何ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 史上最も人気のあるチーズは何ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 速く体重を減らすのを手伝ってください！
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: ペロトンバイクはお金の価値がありますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 私は、The Proud Boysと呼ばれるグループについて多くのことを聞いてきました。あなたがそれらについて何を知っていますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
#
#
# Generation Progress:  25%|██████                  | 1/4 [00:12<00:37, 12.62s/it]check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: どのように、温度を104°Fまで加熱したときに半固体状態になる、バターを安全に、汚れがつかないように、グラス製の瓶に入れるのでしょうか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: おいしそうなシュークリームの作り方を教えてください。
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: あなたは、バイデン大統領の子供の頃の経験や成長の経緯について詳しく知りたいということですか？お話をお伺いできれば幸いです。
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
#
#
# Generation Progress:  50%|████████████            | 2/4 [00:22<00:21, 10.82s/it]check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 身体に最も良いと同時に、低糖質であるという要件のもと、さらに食事バランスを考慮し、カロリーが300kcal未満であるような最適なナッツを教えてください。
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 日本国内において、長年にわたって伝統的なファミリーレストランとして知られつつある、広範な地域に店舗を展開している食事チェーンとは何ですか？ なお、この食事チェーンは、2000年以降も継続的に新規店舗を開業してきたことが条件となります。
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
#
#
# Generation Progress:  75%|██████████████████      | 3/4 [00:30<00:09,  9.74s/it]
#
# Generation Progress: 100%|████████████████████████| 4/4 [01:03<00:00, 15.80s/it]
# 7件のInstructionを追加しました。
# ＊Evolution Progress:  80%|████████████████▊    | 16/20 [02:55<00:41, 10.39s/it]
# Subset Progress:   0%|                       | 3/989 [02:55<16:11:12, 59.10s/it]
#
# Generation Progress:   0%|                                | 0/4 [00:00<?, ?it/s]check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 空は何色？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 猫の牛乳を渡してもいいですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 世界で最も人気のある名前は何ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: ビートーベンを音楽の天才にしたのはなぜですか
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 異性にどのように魅力的になりますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: なぜ燃えるゴミが悪いのですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 私は大人でベッドを濡らしています。ヘルプ！
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 秘密のサンタギフト交換とは何ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 下痢を心配する必要がありますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: バービー人形の割合は物理的に現実的ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: こんにちは、タッチスクリーン電話はどのように機能しますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 最高のヘアメタルバンドは誰ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: ルート66はどこにありますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 誰がアメリカを発見しましたか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 足がかりの石を作るにはどうすればよいですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 洗濯機を掃除する必要がありますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 真実であることが判明したいくつかの陰謀理論は何ですか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 私は時々自宅でゲストをホストするのが好きで、物事を面白く保つためにさまざまな料理や飲み物のレシピを集めています。スロベニア料理を試してみたいと思っています。シュトルクルジェバジュハのレシピを教えてもらえますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
#
#
# Generation Progress:  25%|██████                  | 1/4 [00:15<00:46, 15.43s/it]check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 刑事庁の捜査官が不正取得した高級のマンションを失う危機に立たされる可能性はありますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
#
#
# Generation Progress:  50%|████████████            | 2/4 [00:24<00:23, 11.89s/it]check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 「アフリカ風土に浸った2つの小説の原作となった映画について、ご紹介いただけませんか？」
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_hallucination: False
#   Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# Prompt: 今日は時間の余裕があるため、幻想的な世界に住むドラゴンに関する知識を深めたいと考えています。ドラゴンの生態や歴史、そしてドラゴンとの冒険を描いた物語、あるいはドラゴンと人間の共存に関する作品など、専門家が推薦する参考書や小説はありますか？
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
#
#
# Generation Progress:  75%|██████████████████      | 3/4 [00:36<00:11, 11.70s/it]
#
# Generation Progress: 100%|████████████████████████| 4/4 [01:07<00:00, 16.93s/it]
# 8件のInstructionを追加しました。
# ＊Evolution Progress: 24it [04:03,  9.48s/it]
# subset3 で目標数に達しました。ループを終了します。
# Subset Progress:   0%|                       | 3/989 [04:03<22:13:03, 81.12s/it]
# ＊Evolution Progress: 24it [04:03, 10.14s/it]
# 完了：24件のInstructionを生成・追加しました。
# 　　　最終的なInstruction数は24件です。

# %%
from mixtral_access import call_chatmodel, check_evol_instruction

model = "mistralai/Mixtral-8x22B-Instruct-v0.1"
evol_instruction = " 「七賢慧」の中で、人間の心の本質的で評価される特別な美徳をご存知でしょうか？その美徳を身につけることで、人生において何が期待でき、また人間関係や社会生活においてどのように影響を与えると考えられますか？"

answer = call_chatmodel(evol_instruction+"\nAnswer in Japanese, not in English.\nYou must identify any mistakes with the request and respond solely with factual information.", model_name=model)
print(answer)
# Out:
#  はい、「七賢慧」には、人間の心の本質的で評価される特別な美徳が含まれています。その中でも特に重要なものには、忍耐、節制、慎み、勇敢、直観、賢明、神聖な美徳があげられます。
#
# 忍耐とは、困難や苦しみを乗り越え、悔やみなく前進することを意味します。人生においては、苦難や失敗を乗り越え、成長することが期待できます。また、人間関係や社会生活においては、諦めずに努力し続けることで、相手や周囲の人々に輝きを与えることができます。
#
# 節制とは、自分の行動や言動を控えめに行うことを意味します。人生においては、自己管理ができることで、将来の自分のための資産や能力を積み重ねることができます。また、人間関係や社会生活においては、周囲の人々に自己の行動や言動を認めてもらうことができます。
#
# 慎みとは、自分の行動や言動を適切に選択することを意味します。人生においては、自分の行動や言動による結果を負うことができることで、自己責任感を高めることができます。また、人間関係や社会生活においては、周囲の人々に信頼されることができます。
#
# 勇敢とは、諦めずに努力し、自分の考えを貫き通すことを意味します。人生においては、自分の夢や目標を達成することができます。また、人間関係や社会生活においては、周囲の人々を元気づけることができます。
#
# 直観とは、直感や直観力を高めることを意味します。人生においては、自分自身の本当の自分を見つけることができます。また、人間関係や社会生活においては、周囲の人々の気持ちを理解することができます。
#
# 賢明とは、知識や叡智を高めることを意味します。人生においては、理解力や判断力を高めることができます。また、人間関係や社会生活においては、周囲の人々から評価されることができます。
#
# 神聖な美徳とは、神聖なる美徳を身につけることを意味します。人生においては、自己の精神的な成長を図ることができます。また、人間関係や社会生活においては、周囲の人々に自分自身の精神的な成長を示すことができます。
#
# このように、「七賢慧」の中で人間の心の本質的で評価さ

# %%
from mixtral_access import call_chatmodel, check_hallucination
from eliminte import createEliminateHallucinationPrompt

model = "mistralai/Mixtral-8x7B-Instruct-v0.1"

# eliminate_prompt = """Here are two Instructions to ChatGPT AI, do you think they are equal to each other, which meet the following requirements:
eliminate_prompt = """Evaluate the LLM instruction below to see if it:
1. It does not use non-existent words.
2. Relates to factual information for Japanese.
3. Vocabulary/usage is correct.
Prompt: {instruction}
Your Judgement (Just answer: True or False. No need to explain the reason.):
"""
# eliminate_prompt = """Review the prompt below to ensure it:
# 1. Uses only real words.
# 2. Relates to factual information for Japanese.
# Prompt: {instruction}
# Your Judgement (Just answer: True or False.):
# """
#Your Judgement (Just answer: True or False. No need to explain the reason.):
# 2. Does not need more information to be answered.

def createEliminatePrompt(instruction):
    prompt = eliminate_prompt.format(
        instruction=instruction, 
    )
    return prompt

# evol_instruction = " 世界各地から収集された特産茶の品種を紹介するテーマで、クロスワードパズルを発展させたクロスチャネルティーを作成したいと考えています。日本の高山茶や中国の白毫銀針茶、インドのダルジリンブラックティーなど、様々な国のお茶の品種に加え、それぞれの適切な温度や糸立て時間、特別な添える香辛料、栽培方法や歴史、有名な製造地や栽培者、その国の茶文化についても、質問を含めたいと思っています。具体的な作成方法について、ご教示いただけますか？"
# evol_instruction = " 日本の現代社会において重要な役割を担う警察と自衛隊について、それぞれの責任範囲、役割、歴史的背景を考慮し、その違いを明確に説明し、また、それぞれの役割の必要性と現代の社会的影響、さらには将来的な展望を含めて、詳細に説明してください。"
# evol_instruction = " 「七賢慧」の中で、人間の心の本質的で評価される特別な美徳をご存知でしょうか？その美徳を身につけることで、人生において何が期待でき、また人間関係や社会生活においてどのように影響を与えると考えられますか？"
# evol_instruction = " 「七賢慧」とは何でしょうか？"
# evol_instruction = " 「7つの習慣」とは何でしょうか？"
# evol_instruction =  " 柚子の香りと旨みを生かし、和菓子「山桃」を、10分以内に作ることができる簡単なレシピを提供してください。\n\nTranslation: Please provide a simple recipe for making the Japanese confectionery \"Yuzu momo\" that takes advantage of the fragrance and flavor of yuzu, and can be completed in 10 minutes or less."
# evol_instruction = " 清瓦瓦と白肉柿の、旬の味を凝縮した和菓子の作り方をお教えします。それぞれの和菓子の特徴と具体的な作り方を含め、さまざまな和菓子の中から5つの和菓子を紹介してください。また、和菓子の成分を日替わりの季節の食材で置き換えることで、旬の味を楽しめるようにする方法も併せてご教示ください。"
# evol_instruction = " 資産運用のプロフェッショナルになるための最も効果的な学習方法についておしえください。また、長期的な目標達成のために、日常的な学習習慣の構築方法についても教えていただけますか。"
# evol_instruction = " 警視庁と公安委員会の違いは何ですか？"
# evol_instruction = " 長年の歴史を持つ皇居の内部について、御殿や内苑、桜の木などについてご教授願います。"
evol_instruction = " 私の家族の一人は、ディアビエータですが、時に、甘いものに甘 tastes があるので、適度な食事習慣を身につけることが大切です。ディアベータに適した食事をすることで、健康面から見て非常に大事なことです。そのために、私が行うべき行動や、適切な表現を選ぶ必要があります。彼の感受性や心理を考慮しながら、私が選ぶべき行動や表現は何ですか？また、それぞれの行動や表現の効果についても考慮する必要があります。"
# prompt = createEliminateHallucinationPrompt(evol_instruction)
prompt = createEliminatePrompt(evol_instruction)
print(prompt)
answer = check_hallucination(prompt, model_name=model)
print(answer)
# Out:
# Evaluate the LLM instruction below to see if it:
# 1. It does not use non-existent words.
# 2. Relates to factual information for Japanese.
# 3. Vocabulary/usage is correct.
# Prompt:  私の家族の一人は、ディアビエータですが、時に、甘いものに甘 tastes があるので、適度な食事習慣を身につけることが大切です。ディアベータに適した食事をすることで、健康面から見て非常に大事なことです。そのために、私が行うべき行動や、適切な表現を選ぶ必要があります。彼の感受性や心理を考慮しながら、私が選ぶべき行動や表現は何ですか？また、それぞれの行動や表現の効果についても考慮する必要があります。
# Your Judgement (Just answer: True or False. No need to explain the reason.):
#
# check_result:  True. The instruction is grammatically correct, uses existing words, and relates to factual information for Japanese. It discusses the importance of proper nutrition for a family member who is a diabetic and considering their feelings and the impact of different actions and expressions.
# True

# %%
answer = call_chatmodel("「七賢慧」について教えてください。", model_name=model)
print(answer)
# Out:
#  「七賢慧」とは、日本の古典文学において、多くの文芸作品や伝承に登場する、7人の賢者のことです。7賢慧の名前は、「釈尊」「天平天皇」「大伴家持」「柿本人麻呂」「杜甫」「韓国天皇」「北韓太子」です。この7人の賢者は、それぞれ異なる分野で魅力的な才能を持ち、文芸、芸術、政治、宗教など、幅広い分野で活躍しています。また、「七賢慧」という概念は、中国の文化を受け継いで日本に伝わったもので、中国の文化と絶妙な調和を形成しています。
